# %%
# !pip install xlrd
# !pip install openpyxl
# Out:
# Requirement already satisfied: xlrd in c:\rabeea software\python\lib\site-packages (2.0.1)
# Requirement already satisfied: openpyxl in c:\rabeea software\python\lib\site-packages (3.0.7)
# Requirement already satisfied: et-xmlfile in c:\rabeea software\python\lib\site-packages (from openpyxl) (1.1.0)

# %%
# from google.colab import drive
# drive.mount("/content/drive")

# %%
import pandas as pd
import xlrd


c = pd.read_excel('Retailo Internship - Case Study.xlsx', 3)
data = pd.read_excel('Retailo Internship - Case Study.xlsx', 1)
data["Total"] = data["Price"] * data["Delivered Quantity"]
print(data.shape)
data
# Out:
# (95755, 11)
#       Order Date  Order ID        Type                     Item  Price  \
# 0     2021-01-21    802594  Unassisted         MilkPak 1Ltr x12   1832
# 1     2021-01-21    802838  Unassisted         MilkPak 1Ltr x12   1691
# 2     2021-01-21    802882  Unassisted         MilkPak 1Ltr x12   1785
# 3     2021-01-21    803122  Unassisted         MilkPak 1Ltr x12   1806
# 4     2021-01-21    803156  Unassisted         MilkPak 1Ltr x12   1763
# ...          ...       ...         ...                      ...    ...
# 95750 2021-01-25    965467  Unassisted      Shan Korma 25gm x12    303
# 95751 2021-01-25    965666  Unassisted   Tapal Danedar 190gm x1    185
# 95752 2021-01-25    965666  Unassisted         Tarang 225ml x27    804
# 95753 2021-01-25    965666  Unassisted  Ariel Original 35gm x12    107
# 95754 2021-01-25    965666  Unassisted            Sugar 50Kg x1   4552
#
#        Ordered Quantity  Delivered Quantity  Customer ID  Customer Latitude  \
# 0                     3                   2         1902          25.037971
# 1                     3                   2         1902          25.073391
# 2                     3                   3         1902          25.020362
# 3                     3                   3         1902          25.089387
# 4                     3                   2         1902          25.014007
# ...                 ...                 ...          ...                ...
# 95750                 1                   1        58542          25.011118
# 95751                 3                   3        58546          25.041369
# 95752                 1                   1        58546          25.081773
# 95753                 3                   3        58546          25.034288
# 95754                 1                   1        58546          25.003045
#
#        Customer Longitude  Total
# 0               67.311603   3664
# 1               67.274463   3382
# 2               67.270496   5355
# 3               67.262328   5418
# 4               67.313552   3526
# ...                   ...    ...
# 95750           67.229854    303
# 95751           67.309120    555
# 95752           67.365620    804
# 95753           67.374019    321
# 95754           67.322723   4552
#
# [95755 rows x 11 columns]

# %%
data = data.loc[~(data['Delivered Quantity'] == 0)]
data.shape
# Out:
# (82628, 11)

# %%
cat = pd.read_excel('Retailo Internship - Case Study.xlsx', 2)
cat
# Out:
#                                      Item   Category
# 0                       Everyday 15gm x12       Milk
# 1                       MilkPak 250ml x27       Milk
# 2                   Tapal Danedar 95gm x1        Tea
# 3                         Bunyad 26gm x12       Milk
# 4                Cerelac 3 Fruits 25gm x8  Baby Food
# 5                   Tapal Tezdum 11gm x10        Tea
# 6                     Shan Korma 25gm x12    Recipes
# 7            Shan Bombay Biryani 25gm x12    Recipes
# 8                   Cerelac Wheat 25gm x8  Baby Food
# 9                 Ariel Original 35gm x12  Detergent
# 10           Tapal Family Mixture 95gm x1        Tea
# 11                   Shan Karahi 25gm x12    Recipes
# 12                    Surf Excel 35gm x12  Detergent
# 13                       Tarang 225ml x27       Milk
# 14                          Sugar 50Kg x1    Staples
# 15              Shan Achar Gosht 25gm x12    Recipes
# 16            Tang Orange Sachet 25gm x12     Juices
# 17                 Olper's Milk 250ml x27       Milk
# 18               Mezan Canola Oil 1Ltr x5        Oil
# 19                       MilkPak 1Ltr x12       Milk
# 20        Fruita Vitals Chaunsa 200ml x24     Juices
# 21             Tang Mango Sachet 25gm x12     Juices
# 22          Fruita Vitals Apple 200ml x24     Juices
# 23                 Tapal Danedar 20gm x20        Tea
# 24                      CupShup 225ml x27       Milk
# 25            Areesa Cooking Oil 900ml x5        Oil
# 26                   Shan Nihari 25gm x12    Recipes
# 27                 Mezan Banaspati 1Kg x5        Oil
# 28            Shan Chicken Tikka 25gm x12    Recipes
# 29                 Tapal Danedar 190gm x1        Tea
# 30                  Slice Mango 200ml x24     Juices
# 31                      Olper's 250ml x27       Milk
# 32            Shan Pilau Biryani 25gm x12    Recipes
# 33                         Brite 35gm x12  Detergent
# 34                        Bunyad 260gm x1       Milk
# 35                    Lactogen 1 200gm x1  Baby Food
# 36                 Bonus Tristar 90gm x12  Detergent
# 37  Pakola Flavored Milk Zafran 250ml x12     Juices
# 38                 Bona Papa Large 50s x1  Baby Care
# 39             Tang Lemon Sachet 25gm x12     Juices
# 40                Bona Papa Medium 50s x1  Baby Care
# 41                   Cerelac Rice 25gm x8  Baby Food
# 42              Shan Seekh Kabab 25gm x12    Recipes
# 43           Shan Sindhi Biryani 25gm x12    Recipes
# 44          Tapal Family Mixture 20gm x20        Tea
# 45            Olper's Milk 1Ltr x12 Promo       Milk
# 46                    Lactogen 2 200gm x1  Baby Food
# 47                    Surf Excel 500gm x1  Detergent

# %%
data.shape
# Out:
# (82628, 11)

# %%
p = data.groupby('Order Date').sum()['Total']
p
# Out:
# Order Date
# 2021-01-01     1248754
# 2021-01-02     2321251
# 2021-01-03     2541726
# 2021-01-04     6329251
# 2021-01-05     7289165
# 2021-01-06     4709008
# 2021-01-07     5933438
# 2021-01-08     4762115
# 2021-01-09     5488368
# 2021-01-10     6136691
# 2021-01-11     4656850
# 2021-01-12     4672482
# 2021-01-13     2084571
# 2021-01-14     3477297
# 2021-01-15     6809489
# 2021-01-16     6989703
# 2021-01-17     8291597
# 2021-01-18    19664634
# 2021-01-19    14000884
# 2021-01-20     3707906
# 2021-01-21    10565468
# 2021-01-22    12979374
# 2021-01-23     3760092
# 2021-01-24    12154961
# 2021-01-25     8665412
# 2021-01-26     7107086
# 2021-01-27     5512637
# 2021-01-28     8998938
# 2021-01-29     6287577
# 2021-01-30     3205403
# 2021-01-31     2495981
# Name: Total, dtype: int64

# %% [markdown]
# # TOTAL SALES IN THE MONTH

# %%
import matplotlib.pyplot as plt


p.plot(x='date', y= 'total sales', kind="line")
plt.ylabel('Total Sales')

plt.show()

# %%
m = pd.merge(left=data, right=cat, how='outer', left_on='Item', right_on='Item')
m
# Out:
#       Order Date  Order ID        Type               Item  Price  \
# 0     2021-01-21    802594  Unassisted   MilkPak 1Ltr x12   1832
# 1     2021-01-21    802838  Unassisted   MilkPak 1Ltr x12   1691
# 2     2021-01-21    802882  Unassisted   MilkPak 1Ltr x12   1785
# 3     2021-01-21    803122  Unassisted   MilkPak 1Ltr x12   1806
# 4     2021-01-21    803156  Unassisted   MilkPak 1Ltr x12   1763
# ...          ...       ...         ...                ...    ...
# 82623 2021-01-19    936030    Assisted  CupShup 225ml x27    710
# 82624 2021-01-21    944835    Assisted  CupShup 225ml x27    749
# 82625 2021-01-21    942802    Assisted  CupShup 225ml x27    634
# 82626 2021-01-25    956441  Unassisted  CupShup 225ml x27    737
# 82627 2021-01-24    954484  Unassisted  CupShup 225ml x27    704
#
#        Ordered Quantity  Delivered Quantity  Customer ID  Customer Latitude  \
# 0                     3                   2         1902          25.037971
# 1                     3                   2         1902          25.073391
# 2                     3                   3         1902          25.020362
# 3                     3                   3         1902          25.089387
# 4                     3                   2         1902          25.014007
# ...                 ...                 ...          ...                ...
# 82623                 1                   1        58141          25.064585
# 82624                 1                   1        58243          25.146265
# 82625                 2                   2        58260          24.945119
# 82626                 1                   1        58353          24.976552
# 82627                 1                   1        58407          25.007995
#
#        Customer Longitude  Total Category
# 0               67.311603   3664     Milk
# 1               67.274463   3382     Milk
# 2               67.270496   5355     Milk
# 3               67.262328   5418     Milk
# 4               67.313552   3526     Milk
# ...                   ...    ...      ...
# 82623           67.374723    710     Milk
# 82624           67.269499    749     Milk
# 82625           67.144625   1268     Milk
# 82626           67.305807    737     Milk
# 82627           67.258037    704     Milk
#
# [82628 rows x 12 columns]

# %% [markdown]
# # Items Sold Category Wise

# %%
# ax = m.plot.bar(x='Category', y= 'Ordered Quantity', rot=0)
import seaborn as sns


new = m[['Category', 'Ordered Quantity']]

# %%
# count plot on single categorical variable
sns.countplot(x ='Category', data = new)

sns.set(rc={'figure.figsize':(15,8.27)})
# Show the plot
plt.show()

# %% [markdown]
# For this month, which category gave the company the most commission?

# %%
com = m[['Category', 'Total']]

# %%
c
# Out:
#     Category  Margin
# 0       Milk   0.040
# 1        Tea   0.050
# 2  Baby Food   0.035
# 3    Recipes   0.025
# 4  Detergent   0.080
# 5    Staples   0.060
# 6     Juices   0.040
# 7        Oil   0.015
# 8  Baby Care   0.090

# %%
com = pd.merge(left=com, right=c, how='outer', left_on='Category', right_on='Category')
com
# Out:
#         Category  Total  Margin
# 0           Milk   3664    0.04
# 1           Milk   3382    0.04
# 2           Milk   5355    0.04
# 3           Milk   5418    0.04
# 4           Milk   3526    0.04
# ...          ...    ...     ...
# 82623  Baby Care    666    0.09
# 82624  Baby Care   1398    0.09
# 82625  Baby Care    665    0.09
# 82626  Baby Care    663    0.09
# 82627  Baby Care   1274    0.09
#
# [82628 rows x 3 columns]

# %%
com['commission'] = com['Total'] * com['Margin'] 
com
# Out:
#         Category  Total  Margin  commission
# 0           Milk   3664    0.04      146.56
# 1           Milk   3382    0.04      135.28
# 2           Milk   5355    0.04      214.20
# 3           Milk   5418    0.04      216.72
# 4           Milk   3526    0.04      141.04
# ...          ...    ...     ...         ...
# 82623  Baby Care    666    0.09       59.94
# 82624  Baby Care   1398    0.09      125.82
# 82625  Baby Care    665    0.09       59.85
# 82626  Baby Care    663    0.09       59.67
# 82627  Baby Care   1274    0.09      114.66
#
# [82628 rows x 4 columns]

# %%
# count plot on single categorical variable

com = com[['Category','commission']]
com
# com = com.groupby(['Category']).sum()
# Out:
#         Category  commission
# 0           Milk      146.56
# 1           Milk      135.28
# 2           Milk      214.20
# 3           Milk      216.72
# 4           Milk      141.04
# ...          ...         ...
# 82623  Baby Care       59.94
# 82624  Baby Care      125.82
# 82625  Baby Care       59.85
# 82626  Baby Care       59.67
# 82627  Baby Care      114.66
#
# [82628 rows x 2 columns]

# %% [markdown]
# # Total Products Sold vs Comission

# %%
# com
# sns.countplot(x ='Category', data = com)

# # sns.set(rc={'figure.figsize':(15,8.27)})
# # Show the plot
# plt.show()

# com.groupby('Category')['commission'].sum().plot(kind="line")
# new.groupby('Category')['Ordered Quantity'].sum().plot(kind="bar")
print(new.groupby('Category')['Ordered Quantity'].sum())
fig, ax1 = plt.subplots(figsize=(15, 10))
# ax2 = ax1.twinx()
ax2=new.groupby('Category')['Ordered Quantity'].sum().plot(kind='bar', color='b')
ax1=com.groupby('Category')['commission'].sum().plot(kind='line',color='g', secondary_y=True)


ax1.set_xlabel('X data')
ax1.set_ylabel('Commission', color='g', fontsize=20)
ax2.set_ylabel('Total Items Sold', color='b', fontsize=20)

plt.show()
# Out:
# Category
# Baby Care      3021
# Baby Food     68356
# Detergent     51843
# Juices        28120
# Milk         289623
# Oil           35051
# Recipes       34290
# Staples       14162
# Tea           68715
# Name: Ordered Quantity, dtype: int64

# %% [markdown]
# #   Top 5 Selling Items

# %%
b = m[['Item', 'Delivered Quantity']]

df_p= data.groupby(['Item'])['Delivered Quantity'].sum().sort_values(ascending=False).head()
df_p=df_p.to_frame()
# df_p['Item', 'C'] = df_p
# # 
df_p

# b
# Out:
#                           Delivered Quantity
# Item
# Everyday 15gm x12                     145071
# Cerelac 3 Fruits 25gm x8               27693
# Bunyad 26gm x12                        24894
# MilkPak 250ml x27                      22240
# Tapal Danedar 95gm x1                  18435

# %%
# sns.countplot(x ='Delivered Quantity', data = b).

# sns.set(rc={'figure.figsize':(5,8.27)})
# # Show the plot
# plt.show()

fig = df_p.plot.bar()

# %%
new_all = data[data['Order ID'].duplicated(keep = False)]
new_all.head()
# Out:
#    Order Date  Order ID      Type                         Item  Price  \
# 7  2021-01-10    767286  Assisted          Surf Excel 500gm x1    134
# 8  2021-01-10    767286  Assisted          Surf Excel 35gm x12    108
# 9  2021-01-10    767286  Assisted  Tang Orange Sachet 25gm x12     99
# 10 2021-01-10    767286  Assisted   Tang Mango Sachet 25gm x12    111
# 11 2021-01-10    767374  Assisted  Shan Chicken Tikka 25gm x12    319
#
#     Ordered Quantity  Delivered Quantity  Customer ID  Customer Latitude  \
# 7                  6                   4         1909          34.922574
# 8                  2                   2         1909          34.950171
# 9                  2                   2         1909          34.910916
# 10                 2                   2         1909          34.913342
# 11                 2                   2         1909          34.891581
#
#     Customer Longitude  Total
# 7            34.890238    536
# 8            34.947947    216
# 9            34.914508    198
# 10           34.889580    222
# 11           34.920592    638

# %%
new_all['Product_Bundle'] = new_all.groupby('Order ID')['Item'].transform(lambda x:','.join(x))

new_all.head()
# Out:
# <ipython-input-21-41745b25c7c4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_all['Product_Bundle'] = new_all.groupby('Order ID')['Item'].transform(lambda x:','.join(x))
#    Order Date  Order ID      Type                         Item  Price  \
# 7  2021-01-10    767286  Assisted          Surf Excel 500gm x1    134
# 8  2021-01-10    767286  Assisted          Surf Excel 35gm x12    108
# 9  2021-01-10    767286  Assisted  Tang Orange Sachet 25gm x12     99
# 10 2021-01-10    767286  Assisted   Tang Mango Sachet 25gm x12    111
# 11 2021-01-10    767374  Assisted  Shan Chicken Tikka 25gm x12    319
#
#     Ordered Quantity  Delivered Quantity  Customer ID  Customer Latitude  \
# 7                  6                   4         1909          34.922574
# 8                  2                   2         1909          34.950171
# 9                  2                   2         1909          34.910916
# 10                 2                   2         1909          34.913342
# 11                 2                   2         1909          34.891581
#
#     Customer Longitude  Total  \
# 7            34.890238    536
# 8            34.947947    216
# 9            34.914508    198
# 10           34.889580    222
# 11           34.920592    638
#
#                                        Product_Bundle
# 7   Surf Excel 500gm x1,Surf Excel 35gm x12,Tang O...
# 8   Surf Excel 500gm x1,Surf Excel 35gm x12,Tang O...
# 9   Surf Excel 500gm x1,Surf Excel 35gm x12,Tang O...
# 10  Surf Excel 500gm x1,Surf Excel 35gm x12,Tang O...
# 11  Shan Chicken Tikka 25gm x12,Shan Korma 25gm x1...

# %%
new_all = new_all[['Order ID', 'Product_Bundle']].drop_duplicates()
new_all.head()
# Out:
#     Order ID                                     Product_Bundle
# 7     767286  Surf Excel 500gm x1,Surf Excel 35gm x12,Tang O...
# 11    767374  Shan Chicken Tikka 25gm x12,Shan Korma 25gm x1...
# 23    791751  Tapal Danedar 95gm x1,Tapal Danedar 20gm x20,T...
# 30    815669           MilkPak 250ml x27,Tapal Danedar 190gm x1
# 38    780564  Shan Korma 25gm x12,Shan Chicken Tikka 25gm x1...

# %%
from itertools import combinations
from collections import Counter

count = Counter()

for row in new_all['Product_Bundle']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list,2)))
    
    
top = count.most_common(10)
top
# Out:
# [(('Everyday 15gm x12', 'Cerelac 3 Fruits 25gm x8'), 1250),
#  (('Bunyad 26gm x12', 'Everyday 15gm x12'), 1158),
#  (('Cerelac 3 Fruits 25gm x8', 'Cerelac Wheat 25gm x8'), 1068),
#  (('Everyday 15gm x12', 'Bunyad 26gm x12'), 1052),
#  (('Bunyad 26gm x12', 'Cerelac 3 Fruits 25gm x8'), 1030),
#  (('Tapal Danedar 95gm x1', 'Tapal Family Mixture 95gm x1'), 920),
#  (('Everyday 15gm x12', 'Cerelac Wheat 25gm x8'), 799),
#  (('Ariel Original 35gm x12', 'Surf Excel 35gm x12'), 764),
#  (('Cerelac 3 Fruits 25gm x8', 'Everyday 15gm x12'), 757),
#  (('Bunyad 26gm x12', 'Cerelac Wheat 25gm x8'), 697)]

# %%
val = []
label = []

for i in top:
    label.append(i)
    val.append(i[1])
print(label)
print(val)
# y = np.array([35, 25, 25, 15])
# mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(val, labels = label)
# plt.legend()
# Out:
# [(('Everyday 15gm x12', 'Cerelac 3 Fruits 25gm x8'), 1250), (('Bunyad 26gm x12', 'Everyday 15gm x12'), 1158), (('Cerelac 3 Fruits 25gm x8', 'Cerelac Wheat 25gm x8'), 1068), (('Everyday 15gm x12', 'Bunyad 26gm x12'), 1052), (('Bunyad 26gm x12', 'Cerelac 3 Fruits 25gm x8'), 1030), (('Tapal Danedar 95gm x1', 'Tapal Family Mixture 95gm x1'), 920), (('Everyday 15gm x12', 'Cerelac Wheat 25gm x8'), 799), (('Ariel Original 35gm x12', 'Surf Excel 35gm x12'), 764), (('Cerelac 3 Fruits 25gm x8', 'Everyday 15gm x12'), 757), (('Bunyad 26gm x12', 'Cerelac Wheat 25gm x8'), 697)]
# [1250, 1158, 1068, 1052, 1030, 920, 799, 764, 757, 697]
# ([<matplotlib.patches.Wedge at 0x22213f91670>,
#   <matplotlib.patches.Wedge at 0x22213f919d0>,
#   <matplotlib.patches.Wedge at 0x22213069e80>,
#   <matplotlib.patches.Wedge at 0x2221468a0a0>,
#   <matplotlib.patches.Wedge at 0x2221468a1f0>,
#   <matplotlib.patches.Wedge at 0x2221468a850>,
#   <matplotlib.patches.Wedge at 0x2221468ae20>,
#   <matplotlib.patches.Wedge at 0x222146b0070>,
#   <matplotlib.patches.Wedge at 0x222146b04f0>,
#   <matplotlib.patches.Wedge at 0x222146b0af0>],
#  [Text(1.0072544427763357, 0.4420842538559067, "(('Everyday 15gm x12', 'Cerelac 3 Fruits 25gm x8'), 1250)"),
#   Text(0.3879965446485661, 1.0293000929470344, "(('Bunyad 26gm x12', 'Everyday 15gm x12'), 1158)"),
#   Text(-0.40395551773222194, 1.0231421893821468, "(('Cerelac 3 Fruits 25gm x8', 'Cerelac Wheat 25gm x8'), 1068)"),
#   Text(-0.9688398338143358, 0.5209120620744065, "(('Everyday 15gm x12', 'Bunyad 26gm x12'), 1052)"),
#   Text(-1.0790365221185407, -0.2137292304162538, "(('Bunyad 26gm x12', 'Cerelac 3 Fruits 25gm x8'), 1030)"),
#   Text(-0.7336061419099246, -0.8196475026205081, "(('Tapal Danedar 95gm x1', 'Tapal Family Mixture 95gm x1'), 920)"),
#   Text(-0.176659620542167, -1.0857215934436866, "(('Everyday 15gm x12', 'Cerelac Wheat 25gm x8'), 799)"),
#   Text(0.38322461251071305, -1.0310862700889842, "(('Ariel Original 35gm x12', 'Surf Excel 35gm x12'), 764)"),
#   Text(0.8329799124712591, -0.7184319490524999, "(('Cerelac 3 Fruits 25gm x8', 'Everyday 15gm x12'), 757)"),
#   Text(1.0708786015069152, -0.2514339293623556, "(('Bunyad 26gm x12', 'Cerelac Wheat 25gm x8'), 697)")])

# %%
# !pip install reverse_geocoder
# !pip install pprint
# Out:
# Requirement already satisfied: reverse_geocoder in c:\rabeea software\python\lib\site-packages (1.5.1)
# Requirement already satisfied: scipy>=0.17.1 in c:\rabeea software\python\lib\site-packages (from reverse_geocoder) (1.6.0)
# Requirement already satisfied: numpy>=1.11.0 in c:\rabeea software\python\lib\site-packages (from reverse_geocoder) (1.20.1)
# ERROR: Could not find a version that satisfies the requirement pprint (from versions: none)
# ERROR: No matching distribution found for pprint

# %%
import reverse_geocoder as rg
import pprint
 
def reverseGeocode(coordinates):
    result = rg.search(coordinates)
     
    # result is a list containing ordered dictionary.
    pprint.pprint(result)
 
# Driver function
if __name__=="__main__":
     
    # Coordinates tuple.Can contain more than one pair.
    coordinates =(24.9054624, 67.22734648)
     
    reverseGeocode(coordinates)
# Out:
# Loading formatted geocoded file...
# [{'admin1': 'Sindh',
#   'admin2': '',
#   'cc': 'PK',
#   'lat': '24.9424',
#   'lon': '67.2066',
#   'name': 'Malir Cantonment'}]

# %% [markdown]
# #  Total Assisted and Unassisted orders prices

# %%
# sns.boxplot(x=data['Gender'], y=df['gross income'])
data
# data = data[data['Delivered Quantity'] != 0]
# data
# data = data.drop(data.loc[data['Delivered Quantity']==0].index, inplace=True)
# data
# data = data.query('Delivered Quantity != 0')

# data= data[data['Delivered Quantity'] != 0]
# data

# df = df[(df.T != 0).any()]


# data.loc[~(data==0).all(axis=1)]
# data
# Out:
#       Order Date  Order ID        Type                     Item  Price  \
# 0     2021-01-21    802594  Unassisted         MilkPak 1Ltr x12   1832
# 1     2021-01-21    802838  Unassisted         MilkPak 1Ltr x12   1691
# 2     2021-01-21    802882  Unassisted         MilkPak 1Ltr x12   1785
# 3     2021-01-21    803122  Unassisted         MilkPak 1Ltr x12   1806
# 4     2021-01-21    803156  Unassisted         MilkPak 1Ltr x12   1763
# ...          ...       ...         ...                      ...    ...
# 95750 2021-01-25    965467  Unassisted      Shan Korma 25gm x12    303
# 95751 2021-01-25    965666  Unassisted   Tapal Danedar 190gm x1    185
# 95752 2021-01-25    965666  Unassisted         Tarang 225ml x27    804
# 95753 2021-01-25    965666  Unassisted  Ariel Original 35gm x12    107
# 95754 2021-01-25    965666  Unassisted            Sugar 50Kg x1   4552
#
#        Ordered Quantity  Delivered Quantity  Customer ID  Customer Latitude  \
# 0                     3                   2         1902          25.037971
# 1                     3                   2         1902          25.073391
# 2                     3                   3         1902          25.020362
# 3                     3                   3         1902          25.089387
# 4                     3                   2         1902          25.014007
# ...                 ...                 ...          ...                ...
# 95750                 1                   1        58542          25.011118
# 95751                 3                   3        58546          25.041369
# 95752                 1                   1        58546          25.081773
# 95753                 3                   3        58546          25.034288
# 95754                 1                   1        58546          25.003045
#
#        Customer Longitude  Total
# 0               67.311603   3664
# 1               67.274463   3382
# 2               67.270496   5355
# 3               67.262328   5418
# 4               67.313552   3526
# ...                   ...    ...
# 95750           67.229854    303
# 95751           67.309120    555
# 95752           67.365620    804
# 95753           67.374019    321
# 95754           67.322723   4552
#
# [82628 rows x 11 columns]

# %%
data = data[data['Delivered Quantity'] != 0]
data
# Out:
#       Order Date  Order ID        Type                     Item  Price  \
# 0     2021-01-21    802594  Unassisted         MilkPak 1Ltr x12   1832
# 1     2021-01-21    802838  Unassisted         MilkPak 1Ltr x12   1691
# 2     2021-01-21    802882  Unassisted         MilkPak 1Ltr x12   1785
# 3     2021-01-21    803122  Unassisted         MilkPak 1Ltr x12   1806
# 4     2021-01-21    803156  Unassisted         MilkPak 1Ltr x12   1763
# ...          ...       ...         ...                      ...    ...
# 95750 2021-01-25    965467  Unassisted      Shan Korma 25gm x12    303
# 95751 2021-01-25    965666  Unassisted   Tapal Danedar 190gm x1    185
# 95752 2021-01-25    965666  Unassisted         Tarang 225ml x27    804
# 95753 2021-01-25    965666  Unassisted  Ariel Original 35gm x12    107
# 95754 2021-01-25    965666  Unassisted            Sugar 50Kg x1   4552
#
#        Ordered Quantity  Delivered Quantity  Customer ID  Customer Latitude  \
# 0                     3                   2         1902          25.037971
# 1                     3                   2         1902          25.073391
# 2                     3                   3         1902          25.020362
# 3                     3                   3         1902          25.089387
# 4                     3                   2         1902          25.014007
# ...                 ...                 ...          ...                ...
# 95750                 1                   1        58542          25.011118
# 95751                 3                   3        58546          25.041369
# 95752                 1                   1        58546          25.081773
# 95753                 3                   3        58546          25.034288
# 95754                 1                   1        58546          25.003045
#
#        Customer Longitude  Total
# 0               67.311603   3664
# 1               67.274463   3382
# 2               67.270496   5355
# 3               67.262328   5418
# 4               67.313552   3526
# ...                   ...    ...
# 95750           67.229854    303
# 95751           67.309120    555
# 95752           67.365620    804
# 95753           67.374019    321
# 95754           67.322723   4552
#
# [82628 rows x 11 columns]

# %%
data.groupby(['Type'])['Total'].sum()
# Out:
# Type
# Assisted      145590041
# Unassisted     57258068
# Name: Total, dtype: int64

# %%
data.groupby(['Type']).count()
# Out:
#             Order Date  Order ID   Item  Price  Ordered Quantity  \
# Type
# Assisted         50132     50132  50132  50132             50132
# Unassisted       32496     32496  32496  32496             32496
#
#             Delivered Quantity  Customer ID  Customer Latitude  \
# Type
# Assisted                 50132        50132              50132
# Unassisted               32496        32496              32496
#
#             Customer Longitude  Total
# Type
# Assisted                 50132  50132
# Unassisted               32496  32496

# %%
sns.countplot(x ='Type', data =data)

sns.set(rc={'figure.figsize':(5,8.27)})
# Show the plot
plt.show()

# %%
d= data.groupby(['Order ID', 'Type'])['Total'].sum().reset_index(name ='Total Amount')
d.sort_values(['Total Amount'], ascending=False)
# Out:
#        Order ID        Type  Total Amount
# 29004    931196  Unassisted       3740119
# 30109    938894    Assisted       3296788
# 27280    918522  Unassisted       3114945
# 7130     787204    Assisted       3060031
# 10700    809652  Unassisted       2832453
# ...         ...         ...           ...
# 14189    832779    Assisted            75
# 14155    832666    Assisted            75
# 15504    838542    Assisted            75
# 15370    838038    Assisted            75
# 15128    837348    Assisted            75
#
# [34023 rows x 3 columns]

# %%
# sns.boxplot(x=d['Type'], y=d['Total Amount'])
print(min(d['Total Amount']))
print(max(d['Total Amount']))
# ax = sns.boxplot(x='Type', y='Total Amount', data=d)
# sns.set_theme(style="whitegrid")
# tips = sns.load_dataset("d")
# ax = sns.boxplot(x=tips["Total Amount"])
d.describe()
# Out:
# 75
# 3740119
#             Order ID  Total Amount
# count   34023.000000  3.402300e+04
# mean   850441.984981  5.962088e+03
# std     65024.170542  5.135384e+04
# min    718695.000000  7.500000e+01
# 25%    795232.500000  1.041000e+03
# 50%    845838.000000  1.956000e+03
# 75%    904659.000000  3.836500e+03
# max    968312.000000  3.740119e+06

# %%
# d.boxplot(by ='Type', column =['Total Amount'], grid = False, showfliers=False)
# ax = sns.boxplot(x=d['Type'], y=d['Total Amount'])
# ax.set_ylim(75, 3740119)

ax = plt.figure(figsize=(20,15))
ax = sns.boxplot(x="Type", y="Total Amount", data=d, showfliers = False)
# ax.set_ylim(75,3740119)

# %%
cust = data.groupby(['Order ID', 'Customer ID']).count()
cust
# # print(cust)

customer = data[['Order ID', 'Customer ID']].drop_duplicates()
customer

df1 = customer.groupby('Customer ID')['Order ID'].count().sort_values(ascending=False).head()
df1=df1.to_frame()
df1
# customer.groupby('Customer ID')['Order ID'].count().sort_values(ascending=False)
# customer
# # customer.groupby('Customer ID').count()
# Out:
#              Order ID
# Customer ID
# 2334               57
# 47325              48
# 16578              43
# 27190              38
# 39818              38
